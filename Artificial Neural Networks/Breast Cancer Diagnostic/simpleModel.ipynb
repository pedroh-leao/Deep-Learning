# %% [markdown]
# # Artificial Neural Network to diagnostic breast cancer
# Using Breast Cancer Wisconsin dataset
#
# The diagnosis has two classes for the tumor: malignant = 1, benign = 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
x = pd.read_csv('input_breastCancer.csv')
y = pd.read_csv('output_breastCancer.csv')
x
# Out:
#       radius_mean   texture_mean   perimeter_mean   area_mean  \
# 0           17.99          10.38           122.80      1001.0
# 1           20.57          17.77           132.90      1326.0
# 2           19.69          21.25           130.00      1203.0
# 3           11.42          20.38            77.58       386.1
# 4           20.29          14.34           135.10      1297.0
# ..            ...            ...              ...         ...
# 564         21.56          22.39           142.00      1479.0
# 565         20.13          28.25           131.20      1261.0
# 566         16.60          28.08           108.30       858.1
# 567         20.60          29.33           140.10      1265.0
# 568          7.76          24.54            47.92       181.0
#
#       smoothness_mean   compactness_mean   concavity_mean  \
# 0             0.11840            0.27760          0.30010
# 1             0.08474            0.07864          0.08690
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (426, 30) (426, 1)
# (143, 30) (143, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Dense

# %%
# number of features that will be the input to the model
input_size = x_train.shape[1]

model = Sequential([
    InputLayer(shape= (input_size,)), # input layer
    Dense(units= round((input_size+1) / 2), activation= 'relu', kernel_initializer= 'random_uniform'), # hidden layer
    Dense(units= round((input_size+1) / 2), activation= 'relu', kernel_initializer= 'random_uniform'), # hidden layer
    Dense(units= 1, activation= 'sigmoid') # output layer
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), loss= 'binary_crossentropy', metrics= ['binary_accuracy',])

# %%
model.fit(
    x_train, 
    y_train, 
    batch_size= 10, 
    epochs= 100
)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - binary_accuracy: 0.4679 - loss: 2.2398
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - binary_accuracy: 0.7159 - loss: 0.5062
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - binary_accuracy: 0.7476 - loss: 0.4596
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - binary_accuracy: 0.8690 - loss: 0.3593
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - binary_accuracy: 0.8735 - loss: 0.3535
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - binary_accuracy: 0.8683 - loss: 0.3346
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8709 - loss: 0.3151
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.8735 - loss: 0.3576
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.8684 - loss: 0.2954
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - binary_accuracy: 0.8618 - loss: 0.3012
# Epoch 11/100
# ...

# %%
# two ways to evaluate the model
from sklearn.metrics import accuracy_score

predictions = model.predict(x_test)
predictions = predictions > 0.5
print(accuracy_score(y_test, predictions))

print(model.evaluate(x_test, y_test, batch_size=10))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 0.916083916083916
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9136 - loss: 0.5050
# [0.34892964363098145, 0.9160839319229126]

# %%
# save the model
# model.save('model_breastCancer.keras')

# load the model
# model = tf.keras.models.load_model('model_breastCancer.keras')
