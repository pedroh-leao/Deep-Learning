# %% [markdown]
# # Artificial Neural Network to classify the type of Iris flower
# Using Iris dataset from Fisher
#
# The dataset has three classes for the Iris: Iris Setosa, Iris Versicolour or Iris Virginica
#
# Performing a 10-fold Cross Validation

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils as np_utils
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import backend as k
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score

# %%
dataset = pd.read_csv('iris.csv')
x = dataset.iloc[:, 0:4].values
y = dataset.iloc[:, 4].values

# %%
labelEncoder = LabelEncoder()
y = labelEncoder.fit_transform(y)
y = np_utils.to_categorical(y)

# %%
def create_model():
    k.clear_session()

    input_size = x.shape[1]
    output_size = y.shape[1]

    model = Sequential([
        InputLayer(shape= (input_size, )),
        Dense(units= round((input_size + output_size) / 2), activation= 'relu'),
        Dense(units= round((input_size + output_size) / 2), activation= 'relu'),
        Dense(units= output_size, activation= 'softmax')
    ])

    model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['categorical_accuracy', ])

    return model

# %%
model = KerasClassifier(model= create_model, epochs= 250, batch_size= 10)

# %%
results = cross_val_score(estimator= model, X= x, y= y, cv= 10, scoring= 'accuracy')
# Out:
# Epoch 1/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.3561 - loss: 1.6945
# Epoch 2/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.3259 - loss: 1.7242
# Epoch 3/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.3528 - loss: 1.5406
# Epoch 4/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - categorical_accuracy: 0.2761 - loss: 1.4428
# Epoch 5/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.3751 - loss: 1.3645
# Epoch 6/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - categorical_accuracy: 0.4281 - loss: 1.3325
# Epoch 7/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - categorical_accuracy: 0.3844 - loss: 1.2386
# Epoch 8/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.3452 - loss: 1.3107
# Epoch 9/250
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.3886 - loss: 1.21650
# Epoch 10/250
# ...

# %%
results
# Out:
# array([1.        , 1.        , 1.        , 0.8       , 0.8       ,
#        0.93333333, 0.6       , 1.        , 0.86666667, 1.        ])

# %%
results.mean()
# Out:
# 0.9

# %%
results.std()
# Out:
# 0.12736648783028534
